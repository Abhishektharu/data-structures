# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_rows = 10

# %%
df = pd.read_csv('solar.csv')

# %%
df
# Out:
#          UNIXTime                   Data      Time  Radiation  Temperature  \
# 0      1475229326  9/29/2016 12:00:00 AM  23:55:26       1.21           48
# 1      1475229023  9/29/2016 12:00:00 AM  23:50:23       1.21           48
# 2      1475228726  9/29/2016 12:00:00 AM  23:45:26       1.23           48
# 3      1475228421  9/29/2016 12:00:00 AM  23:40:21       1.21           48
# 4      1475228124  9/29/2016 12:00:00 AM  23:35:24       1.17           48
# ...           ...                    ...       ...        ...          ...
# 32681  1480587604  12/1/2016 12:00:00 AM  00:20:04       1.22           44
# 32682  1480587301  12/1/2016 12:00:00 AM  00:15:01       1.17           44
# 32683  1480587001  12/1/2016 12:00:00 AM  00:10:01       1.20           44
# 32684  1480586702  12/1/2016 12:00:00 AM  00:05:02       1.23           44
# 32685  1480586402  12/1/2016 12:00:00 AM  00:00:02       1.20           44
#
# ...

# %%
chunker = pd.read_csv('solar.csv', chunksize=1000)

# %%
import sys

# %%
#pip install beautifulsoup4 html5lib

# %%
import lxml

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/Top_Gun:_Maverick')

# %%
len(tables)
# Out:
# 26

# %%
tables[0]
# Out:
#             Top Gun: Maverick  \
# 0   Theatrical release poster
# 1                 Directed by
# 2               Screenplay by
# 3                    Story by
# 4                    Based on
# ..                        ...
# 13               Running time
# 14                    Country
# 15                   Language
# 16                     Budget
# 17                 Box office
#
#                                   Top Gun: Maverick.1
# 0                           Theatrical release poster
# 1                                     Joseph Kosinski
# 2   .mw-parser-output .plainlist ol,.mw-parser-out...
# 3                            Peter Craig Justin Marks
# 4                  Charactersby Jim CashJack Epps Jr.
# ..                                                ...
# 13                                     130 minutes[1]
# 14                                      United States
# 15                                            English
# ...

# %%
tables[1]
# Out:
#     0                                                  1
# 0 NaN  This section may lend undue weight to certain ...

# %%
tables
# Out:
# [            Top Gun: Maverick  \
#  0   Theatrical release poster
#  1                 Directed by
#  2               Screenplay by
#  3                    Story by
#  4                    Based on
#  ..                        ...
#  13               Running time
#  14                    Country
#  15                   Language
#  16                     Budget
#  17                 Box office
#
#                                    Top Gun: Maverick.1
#  0                           Theatrical release poster
#  1                                     Joseph Kosinski
#  2   .mw-parser-output .plainlist ol,.mw-parser-out...
#  3                            Peter Craig Justin Marks
#  4                  Charactersby Jim CashJack Epps Jr.
#  ..                                                ...
#  13                                     130 minutes[1]
#  14                                      United States
#  15                                            English
# ...

# %%
top_movies = pd.read_html('https://www.imdb.com/chart/top/')

# %%
len(top_movies)
# Out:
# 1

# %%
#interacting with web APIs

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
len(data)
# Out:
# 30

# %%
data[0] ['title']
# Out:
# 'BUG: Setting values on df with added column has no effect (pandas 2.0 regression)'

# %%
top = pd.read_html('https://www.iqair.com/world-most-polluted-countries')

# %%
top
# Out:
# [     Rank                     Country/Region  2022  2021  2020  2019  2018  \
#  0       1                               Chad  89.7  75.9     -     -     -
#  1       2                               Iraq  80.1  49.7     -  39.6     -
#  2       3                           Pakistan  70.9  66.8    59  65.8  74.3
#  3       4                            Bahrain  66.6  49.8  39.7  46.8  59.8
#  4       5                         Bangladesh  65.8  76.9  77.1  83.3  97.1
#  ..    ...                                ...   ...   ...   ...   ...   ...
#  126   127  Bonaire, Saint Eustatius and Saba   3.3   5.1     -     -     -
#  127   128                            Bermuda   3.0     -     -     -     -
#  128   129                U.S. Virgin Islands   2.9   4.5   3.7   3.5     -
#  129   130                   French Polynesia   2.5     -     -     -     -
#  130   131                               Guam   1.3     -     -     -     -
#
#       Population
#  0      17179740
#  1      43533592
# ...

# %%
df = top[0]

# %%
df.sample(50)
# Out:
#      Rank Country/Region  2022  2021  2020  2019  2018  Population
# 27     28       Mongolia  29.5  33.1  46.6    62  58.5     3347782
# 120   121    New Zealand   4.8   6.8     7   7.5   7.7     5122600
# 79     80        Hungary  12.6  15.5  14.3  14.6  16.8     9709891
# 101   102         Angola   8.8    11    13  15.9     -    34503774
# 91     92        Austria  10.6  11.4  10.9  12.2    15     8955797
# ..    ...            ...   ...   ...   ...   ...   ...         ...
# 121   122    Puerto Rico   4.3   4.8   3.7  10.2  13.7     3263584
# 89     90       Maldives  10.9     -     -     -     -      521457
# 24     25          China  30.6  32.6  34.7  39.1  41.2  1412360000
# 39     40     Kazakhstan  23.0  31.1  21.9  23.6  29.8    19000988
# 118   119        Finland   5.0   5.5     5   5.6   6.6     5541017
#
# [50 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Rank', 'Country/Region', '2022', '2021', '2020', '2019', '2018',
#        'Population'],
#       dtype='object')

# %%
most_polluted_cities = pd.read_html('https://www.iqair.com/world-most-polluted-cities')

# %%
len(most_polluted_cities)
# Out:
# 1

# %%
most_polluted_cities
# Out:
# [    Rank                City  2022    JAN    FEB    MAR    APR    MAY    JUN  \
#  0      1    Lahore, Pakistan  97.4    133  102.5   85.6   69.3   60.9   52.1
#  1      2        Hotan, China  94.3   61.7   91.6  132.7  106.2  120.5   69.5
#  2      3      Bhiwadi, India  92.7  110.6   98.0  116.2  149.5  123.8  102.8
#  3      4  Delhi (NCT), India  92.6    141  100.9   91.0   98.0   73.2   56.2
#  4      5  Peshawar, Pakistan  91.8  110.2  103.5   78.3   68.5   53.5   56.3
#  ..   ...                 ...   ...    ...    ...    ...    ...    ...    ...
#  45    46       Ambala, India  67.1   90.4   55.4   71.1   66.9   65.3   64.8
#  46    47     Manama, Bahrain  66.6   52.6   72.3   67.9   57.0   92.1   68.4
#  47    48       Kanpur, India  66.2  145.2  102.2   79.2   61.1   51.7   55.3
#  48    49   Dhaka, Bangladesh  65.8  133.1  103.2   79.9   42.2   45.0   35.3
#  49    50    Fatehabad, India  65.7   71.4   57.3   65.6   84.6   90.4   64.0
#
# ...
